# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data_files/athlete_events.csv')
noc = pd.read_csv('data_files/noc_regions.csv')
data = pd.merge(df, noc, how='left', on='NOC')
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
# Cleaning up DataFrame
data.drop(['Team', 'NOC', 'Games', 'City', 'Event', 'notes'], axis=1, inplace=True)
data.rename(columns = {'region':'Country'}, inplace = True)

data['Medal'].fillna('None', inplace = True)
data['Height'].fillna('N/A', inplace = True)
data['Weight'].fillna('N/A', inplace = True)
# data['BMI'] = data['Weight'] / (data['Height'] * data['Height'])
data = data.drop_duplicates()
data.head()
# Out:
#    ID                      Name Sex   Age Height Weight  Year  Season  \
# 0   1                 A Dijiang   M  24.0    180     80  1992  Summer
# 1   2                  A Lamusi   M  23.0    170     60  2012  Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0    N/A    N/A  1920  Summer
# 3   4      Edgar Lindenau Aabye   M  34.0    N/A    N/A  1900  Summer
# 4   5  Christine Jacoba Aaftink   F  21.0    185     82  1988  Winter
#
#            Sport Medal      Country
# 0     Basketball  None        China
# 1           Judo  None        China
# 2       Football  None      Denmark
# 3     Tug-Of-War  Gold      Denmark
# 4  Speed Skating  None  Netherlands

# %%
summer = data.loc[data['Season']=='Summer']
summer.head()
# Out:
#     ID                                Name Sex   Age Height Weight  Year  \
# 0    1                           A Dijiang   M  24.0    180     80  1992
# 1    2                            A Lamusi   M  23.0    170     60  2012
# 2    3                 Gunnar Nielsen Aaby   M  24.0    N/A    N/A  1920
# 3    4                Edgar Lindenau Aabye   M  34.0    N/A    N/A  1900
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0    168    N/A  1932
#
#     Season       Sport Medal      Country
# 0   Summer  Basketball  None        China
# 1   Summer        Judo  None        China
# 2   Summer    Football  None      Denmark
# 3   Summer  Tug-Of-War  Gold      Denmark
# 26  Summer   Athletics  None  Netherlands

# %%
# Number of countries participated the Olympics (Many countries boycotted the 1980 olympics)
plt.figure(figsize=(12,8))
#data.groupby('Year')['Country'].nunique().plot(kind='bar',color='blue')
summer.groupby('Year')['Country'].nunique().plot(kind='bar',color='blue')
plt.xticks(rotation = 90)
plt.ylabel("Number of Countries")
plt.title("Countries at the Summer Olympics")
# Out:
# Text(0.5, 1.0, 'Countries at the Summer Olympics')

# %%
# Generate a pie plot showing the population of female versus male
sex = data.groupby("Sex")["Sex"].count()
colors = ["pink", "lightskyblue"]
sex_data = sex.plot(kind="pie", colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis("equal")
sex_data.set_title(label= "Male vs Female Population", fontweight = "bold")
sex_data.set_ylabel("Sex", fontweight = "bold")
plt.tight_layout()
# sex_data.figure.savefig("Images/piecharts_pandas.png")
plt.show()
plt.close()

# %%
# Generate a pie plot showing above in early days vs recent years

# %%
plt.figure
summer.groupby('Year')['ID'].nunique().plot(color='blue',marker='o')
plt.ylabel("Total Number of Athletes")
plt.title("Athletes at the Olympic Games")
# Out:
# Text(0.5, 1.0, 'Athletes at the Olympic Games')

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,1,2)
summer.loc[summer['Sex']=='M'].groupby('Year')['ID'].nunique().plot(color='b',marker='o',label='Male Athletes')
summer.loc[summer['Sex']=='F'].groupby('Year')['ID'].nunique().plot(color='r',marker='o',label='Female Athletes')
plt.ylabel("Number of Athletes")
plt.legend(loc='upper left')
plt.title("Athletes at the Olympic Games by Sex")
# Out:
# Text(0.5, 1.0, 'Athletes at the Olympic Games by Sex')
